# %% [markdown]
# # Template to run MLflow project on Colab
#
# 1. Use companion notebook MLflow Github to update repository
# 2. Mount drive and move to project directory
# 3. Install any libraries that are missing (e.g., mlflow)
# 4. Run the entry point as required as local
# 5. Download run information from mlruns

# %%
# Change the following details to the active project

GLOBAL_PARENT_DIRECTORY = '/content/drive/My Drive/projects/'
GLOBAL_PROJECT_NAME = 'mlflow-example'

# %%
import os

if 'google.colab' in str(get_ipython()):

    print('Running on CoLab')

    from google.colab import drive
    drive.mount("/content/drive")

    #path = GLOBAL_PARENT_DIRECTORY
    path = os.path.join(GLOBAL_PARENT_DIRECTORY, GLOBAL_PROJECT_NAME)

    if os.getcwd() != path:
        os.chdir(path)

else:
    print('This notebook is for Colab development only')
# Out:
# Running on CoLab
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content/drive/My Drive/projects/mlflow-example

# %%
# !pip install mlflow
import mlflow
# Out:
# ...
#      |████████████████████████████████| 14.2MB 540kB/s
# ...
#      |████████████████████████████████| 81kB 9.4MB/s
# ...
#      |████████████████████████████████| 153kB 54.4MB/s
# ...
#      |████████████████████████████████| 348kB 49.9MB/s
# ...
#      |████████████████████████████████| 1.1MB 57.6MB/s
# ...
#      |████████████████████████████████| 61kB 6.5MB/s
# ...
#      |████████████████████████████████| 163kB 45.3MB/s
# ...
#      |████████████████████████████████| 204kB 44.5MB/s
# ...
#      |████████████████████████████████| 92kB 5.4MB/s
# ...
#      |████████████████████████████████| 2.6MB 52.2MB/s
# ...
#      |████████████████████████████████| 133kB 46.1MB/s
# ...
#      |████████████████████████████████| 481kB 31.2MB/s
# ...
#      |████████████████████████████████| 71kB 7.7MB/s
# ...
#      |████████████████████████████████| 51kB 6.6MB/s
# ...
#   Created wheel for prometheus-flask-exporter: filename=prometheus_flask_exporter-0.18.1-cp36-none-any.whl size=17159 sha256=ff764cd373d59da5d4126dee46981efcafaa27e206b90e63375a0b2756e68b5d
# ...

# %%
# %run train.py 0.5 0.5
# Out:
# Elasticnet model (alpha=0.500000, l1_ratio=0.500000):
#   RMSE: 0.82224284975954
#   MAE: 0.6278761410160693
#   R2: 0.12678721972772689

# %%
# %ls mlruns/0/
# Out:
# 31604cfb393645d786e264ea6289c76f/  meta.yaml
